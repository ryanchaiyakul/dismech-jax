# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from animate import animate

jax.config.update("jax_enable_x64", True)

# %%
from Energy_NN_architectures import *

K_init = jnp.array([0.2, 0.0, 0.02])

# train_data = "../data/output_old.npz"
# valid_data = "../data/output_valid.npz"

train_data = "../data/combined_output_new_train.npz"
valid_data = "../data/combined_output_new_test.npz"

train_file = "training_data.npz"
valid_file = "validation_data.npz"
# convert to direct-BC format
convert_linear_bc_to_direct_bc(train_data, train_file, lambdas=None)
convert_linear_bc_to_direct_bc(valid_data, valid_file, lambdas=None)
# Out:
# Saved converted direct-BC dataset to: training_data.npz
# qs.shape      = (2, 11, 11)
# xb.shape      = (2, 11, 8)
# idx_b.shape   = (8,)
# lambdas.shape = (11,)
# Saved converted direct-BC dataset to: validation_data.npz
# qs.shape      = (2, 11, 11)
# xb.shape      = (2, 11, 8)
# idx_b.shape   = (8,)
# lambdas.shape = (11,)

# %%
from properties import Properties

properties = Properties(
    length = 0.5,
    r0 = 0.005,
    axs = None,
    jxs = None,
    ixs1 = None,
    ixs2 = None,
    density = 800.0,
    E = 1e6,
    N = 3,
    # start = jax.numpy.array([0, 0, 0]),
    # end = jax.numpy.array([0.266166, 0., 0.01240256]),
    mass = 0.647
)

params = ModelParams(
    der_K=K_init,
    key=jax.random.PRNGKey(0),
    hidden=(10,),
    which_case="MLP",
    corr_factor=1,
    input_mode="raw",
    zero_reference=True,
    activation="tanh"
)

# %%
final_model, train_history, valid_history = train_model(properties=properties, model_cls=CholeskyPlusStiffnessNN, params=params, train_file=train_file, valid_file=valid_file, n_epochs=5000, lr=5e-2)
# Out:
# Epoch 000 | Train: 1.224e-03 | Valid: 6.495e-04
# Epoch 010 | Train: 5.004e-05 | Valid: 3.253e-05
# Epoch 020 | Train: 7.385e-05 | Valid: 6.935e-05
# Epoch 030 | Train: 4.422e-05 | Valid: 2.720e-05
# Epoch 040 | Train: 4.221e-05 | Valid: 3.955e-05
# Epoch 050 | Train: 3.539e-05 | Valid: 3.046e-05
# Epoch 060 | Train: 2.626e-05 | Valid: 2.261e-05
# Epoch 070 | Train: 1.453e-05 | Valid: 1.342e-05
# Epoch 080 | Train: 7.171e-06 | Valid: 8.047e-06
# Epoch 090 | Train: 1.668e-06 | Valid: 7.599e-06
# Epoch 100 | Train: 1.687e-05 | Valid: 1.668e-05
# Epoch 110 | Train: 7.934e-06 | Valid: 6.083e-06
# Epoch 120 | Train: 3.052e-06 | Valid: 4.493e-06
# Epoch 130 | Train: 1.063e-06 | Valid: 4.613e-06
# Epoch 140 | Train: 8.159e-07 | Valid: 5.116e-06
# Epoch 150 | Train: 6.116e-07 | Valid: 4.660e-06
# Epoch 160 | Train: 4.774e-07 | Valid: 4.189e-06
# Epoch 170 | Train: 4.224e-07 | Valid: 3.991e-06
# Epoch 180 | Train: 3.806e-07 | Valid: 3.925e-06
# Epoch 190 | Train: 3.505e-07 | Valid: 3.893e-06
# Epoch 200 | Train: 3.248e-07 | Valid: 3.861e-06
# Epoch 210 | Train: 3.013e-07 | Valid: 3.825e-06
# Epoch 220 | Train: 2.799e-07 | Valid: 3.815e-06
# Epoch 230 | Train: 2.602e-07 | Valid: 3.811e-06
# Epoch 240 | Train: 2.419e-07 | Valid: 3.808e-06
# Epoch 250 | Train: 2.250e-07 | Valid: 3.807e-06
# Epoch 260 | Train: 2.093e-07 | Valid: 3.807e-06
# Epoch 270 | Train: 1.948e-07 | Valid: 3.809e-06
# Epoch 280 | Train: 1.813e-07 | Valid: 3.812e-06
# Epoch 290 | Train: 1.688e-07 | Valid: 3.816e-06
# Epoch 300 | Train: 1.571e-07 | Valid: 3.821e-06
# Epoch 310 | Train: 1.463e-07 | Valid: 3.829e-06
# Epoch 320 | Train: 2.738e-07 | Valid: 4.124e-06
# Epoch 330 | Train: 1.634e-05 | Valid: 1.589e-05
# Epoch 340 | Train: 6.678e-06 | Valid: 5.562e-06
# Epoch 350 | Train: 9.776e-07 | Valid: 5.928e-06
# Epoch 360 | Train: 3.042e-07 | Valid: 3.977e-06
# Epoch 370 | Train: 3.104e-07 | Valid: 3.986e-06
# Epoch 380 | Train: 2.700e-07 | Valid: 3.799e-06
# Epoch 390 | Train: 1.901e-07 | Valid: 3.777e-06
# Epoch 400 | Train: 1.396e-07 | Valid: 3.794e-06
# Epoch 410 | Train: 1.261e-07 | Valid: 3.763e-06
# Epoch 420 | Train: 1.113e-07 | Valid: 3.765e-06
# Epoch 430 | Train: 1.005e-07 | Valid: 3.772e-06
# Epoch 440 | Train: 9.099e-08 | Valid: 3.771e-06
# Epoch 450 | Train: 8.310e-08 | Valid: 3.765e-06
# Epoch 460 | Train: 7.600e-08 | Valid: 3.758e-06
# Epoch 470 | Train: 6.966e-08 | Valid: 3.753e-06
# Epoch 480 | Train: 6.399e-08 | Valid: 3.747e-06
# Epoch 490 | Train: 5.889e-08 | Valid: 3.742e-06
# Epoch 500 | Train: 5.430e-08 | Valid: 3.737e-06
# Epoch 510 | Train: 5.016e-08 | Valid: 3.731e-06
# Epoch 520 | Train: 4.642e-08 | Valid: 3.726e-06
# Epoch 530 | Train: 4.305e-08 | Valid: 3.721e-06
# Epoch 540 | Train: 4.000e-08 | Valid: 3.715e-06
# Epoch 550 | Train: 3.725e-08 | Valid: 3.710e-06
# Epoch 560 | Train: 3.476e-08 | Valid: 3.704e-06
# Epoch 570 | Train: 3.250e-08 | Valid: 3.698e-06
# Epoch 580 | Train: 3.046e-08 | Valid: 3.692e-06
# Epoch 590 | Train: 2.860e-08 | Valid: 3.686e-06
# Epoch 600 | Train: 2.691e-08 | Valid: 3.679e-06
# Epoch 610 | Train: 2.537e-08 | Valid: 3.673e-06
# Epoch 620 | Train: 2.397e-08 | Valid: 3.666e-06
# Epoch 630 | Train: 2.269e-08 | Valid: 3.658e-06
# Epoch 640 | Train: 2.152e-08 | Valid: 3.651e-06
# Epoch 650 | Train: 2.044e-08 | Valid: 3.643e-06
# Epoch 660 | Train: 1.945e-08 | Valid: 3.635e-06
# Epoch 670 | Train: 1.853e-08 | Valid: 3.627e-06
# Epoch 680 | Train: 1.769e-08 | Valid: 3.619e-06
# Epoch 690 | Train: 1.691e-08 | Valid: 3.610e-06
# Epoch 3050 | Train: 2.131e-09 | Valid: 2.584e-06
# Epoch 3060 | Train: 2.127e-09 | Valid: 2.583e-06
# Epoch 3070 | Train: 2.122e-09 | Valid: 2.583e-06
# Epoch 3080 | Train: 2.118e-09 | Valid: 2.582e-06
# Epoch 3090 | Train: 2.114e-09 | Valid: 2.581e-06
# Epoch 3100 | Train: 2.110e-09 | Valid: 2.581e-06
# Epoch 3110 | Train: 2.107e-09 | Valid: 2.580e-06
# Epoch 3120 | Train: 2.103e-09 | Valid: 2.580e-06
# Epoch 3130 | Train: 2.099e-09 | Valid: 2.579e-06
# Epoch 3140 | Train: 2.095e-09 | Valid: 2.579e-06
# Epoch 3150 | Train: 2.091e-09 | Valid: 2.578e-06
# Epoch 3160 | Train: 2.088e-09 | Valid: 2.578e-06
# Epoch 3170 | Train: 2.084e-09 | Valid: 2.577e-06
# Epoch 3180 | Train: 2.081e-09 | Valid: 2.576e-06
# Epoch 3190 | Train: 2.077e-09 | Valid: 2.576e-06
# Epoch 3200 | Train: 2.074e-09 | Valid: 2.575e-06
# Epoch 3210 | Train: 2.070e-09 | Valid: 2.575e-06
# Epoch 3220 | Train: 2.067e-09 | Valid: 2.574e-06
# Epoch 3230 | Train: 2.064e-09 | Valid: 2.574e-06
# Epoch 3240 | Train: 2.060e-09 | Valid: 2.574e-06
# Epoch 3250 | Train: 2.057e-09 | Valid: 2.573e-06
# Epoch 3260 | Train: 2.054e-09 | Valid: 2.573e-06
# Epoch 3270 | Train: 2.051e-09 | Valid: 2.572e-06
# Epoch 3280 | Train: 2.048e-09 | Valid: 2.572e-06
# Epoch 3290 | Train: 2.044e-09 | Valid: 2.571e-06
# Epoch 3300 | Train: 2.041e-09 | Valid: 2.571e-06
# Epoch 3310 | Train: 2.038e-09 | Valid: 2.570e-06
# Epoch 3320 | Train: 2.035e-09 | Valid: 2.570e-06
# Epoch 3330 | Train: 2.032e-09 | Valid: 2.570e-06
# Epoch 3340 | Train: 2.030e-09 | Valid: 2.569e-06
# Epoch 3350 | Train: 2.027e-09 | Valid: 2.569e-06
# Epoch 3360 | Train: 2.024e-09 | Valid: 2.568e-06
# Epoch 3370 | Train: 2.021e-09 | Valid: 2.568e-06
# Epoch 3380 | Train: 2.018e-09 | Valid: 2.568e-06
# Epoch 3390 | Train: 2.015e-09 | Valid: 2.567e-06
# Epoch 3400 | Train: 2.013e-09 | Valid: 2.567e-06
# Epoch 3410 | Train: 2.010e-09 | Valid: 2.567e-06
# Epoch 3420 | Train: 2.007e-09 | Valid: 2.566e-06
# Epoch 3430 | Train: 2.005e-09 | Valid: 2.566e-06
# Epoch 3440 | Train: 2.002e-09 | Valid: 2.565e-06
# Epoch 3450 | Train: 2.000e-09 | Valid: 2.565e-06
# Epoch 3460 | Train: 1.997e-09 | Valid: 2.565e-06
# Epoch 3470 | Train: 1.994e-09 | Valid: 2.564e-06
# Epoch 3480 | Train: 1.992e-09 | Valid: 2.564e-06
# Epoch 3490 | Train: 1.989e-09 | Valid: 2.564e-06
# Epoch 3500 | Train: 1.987e-09 | Valid: 2.563e-06
# Epoch 3510 | Train: 1.985e-09 | Valid: 2.563e-06
# Epoch 3520 | Train: 1.982e-09 | Valid: 2.563e-06
# Epoch 3530 | Train: 1.980e-09 | Valid: 2.563e-06
# Epoch 3540 | Train: 1.978e-09 | Valid: 2.562e-06
# Epoch 3550 | Train: 1.975e-09 | Valid: 2.562e-06
# Epoch 3560 | Train: 1.973e-09 | Valid: 2.562e-06
# Epoch 3570 | Train: 1.971e-09 | Valid: 2.561e-06
# Epoch 3580 | Train: 1.968e-09 | Valid: 2.561e-06
# Epoch 3590 | Train: 1.966e-09 | Valid: 2.561e-06
# Epoch 3600 | Train: 1.964e-09 | Valid: 2.560e-06
# Epoch 3610 | Train: 1.962e-09 | Valid: 2.560e-06
# Epoch 3620 | Train: 1.960e-09 | Valid: 2.560e-06
# Epoch 3630 | Train: 1.957e-09 | Valid: 2.560e-06
# Epoch 3640 | Train: 1.955e-09 | Valid: 2.559e-06
# Epoch 3650 | Train: 1.953e-09 | Valid: 2.559e-06
# Epoch 3660 | Train: 1.951e-09 | Valid: 2.559e-06
# Epoch 3670 | Train: 1.949e-09 | Valid: 2.559e-06
# Epoch 3680 | Train: 1.947e-09 | Valid: 2.558e-06
# Epoch 3690 | Train: 1.945e-09 | Valid: 2.558e-06
# Epoch 3700 | Train: 1.943e-09 | Valid: 2.558e-06
# Epoch 3710 | Train: 1.941e-09 | Valid: 2.558e-06
# Epoch 3720 | Train: 1.939e-09 | Valid: 2.557e-06
# Epoch 3730 | Train: 1.937e-09 | Valid: 2.557e-06
# Epoch 3740 | Train: 1.935e-09 | Valid: 2.557e-06
# Epoch 3750 | Train: 1.933e-09 | Valid: 2.557e-06
# Epoch 3760 | Train: 1.931e-09 | Valid: 2.556e-06
# Epoch 3770 | Train: 1.929e-09 | Valid: 2.556e-06
# Epoch 3780 | Train: 1.928e-09 | Valid: 2.556e-06
# Epoch 3790 | Train: 1.926e-09 | Valid: 2.556e-06
# Epoch 3800 | Train: 1.924e-09 | Valid: 2.556e-06
# Epoch 3810 | Train: 1.922e-09 | Valid: 2.555e-06
# Epoch 3820 | Train: 1.920e-09 | Valid: 2.555e-06
# Epoch 3830 | Train: 1.919e-09 | Valid: 2.555e-06
# Epoch 3840 | Train: 1.917e-09 | Valid: 2.555e-06
# Epoch 3850 | Train: 1.915e-09 | Valid: 2.555e-06
# Epoch 3860 | Train: 1.913e-09 | Valid: 2.554e-06
# Epoch 3870 | Train: 1.912e-09 | Valid: 2.554e-06
# Epoch 3880 | Train: 1.910e-09 | Valid: 2.554e-06
# Epoch 3890 | Train: 1.908e-09 | Valid: 2.554e-06
# Epoch 3900 | Train: 1.907e-09 | Valid: 2.554e-06
# Epoch 3910 | Train: 1.905e-09 | Valid: 2.553e-06
# Epoch 3920 | Train: 1.903e-09 | Valid: 2.553e-06
# Epoch 3930 | Train: 1.902e-09 | Valid: 2.553e-06
# Epoch 3940 | Train: 1.900e-09 | Valid: 2.553e-06
# Epoch 3950 | Train: 1.898e-09 | Valid: 2.553e-06
# Epoch 3960 | Train: 1.897e-09 | Valid: 2.552e-06
# Epoch 3970 | Train: 1.895e-09 | Valid: 2.552e-06
# Epoch 3980 | Train: 1.894e-09 | Valid: 2.552e-06
# Epoch 4920 | Train: 1.783e-09 | Valid: 2.542e-06
# Epoch 4930 | Train: 1.782e-09 | Valid: 2.542e-06
# Epoch 4940 | Train: 1.781e-09 | Valid: 2.542e-06
# Epoch 4950 | Train: 1.780e-09 | Valid: 2.542e-06
# Epoch 4960 | Train: 1.779e-09 | Valid: 2.541e-06
# Epoch 4970 | Train: 1.778e-09 | Valid: 2.541e-06
# Epoch 4980 | Train: 1.777e-09 | Valid: 2.541e-06
# Epoch 4990 | Train: 1.776e-09 | Valid: 2.541e-06

# %%
import matplotlib.pyplot as plt
train_np = np.asarray(train_history, dtype=float).reshape(-1)
valid_np = np.asarray(valid_history, dtype=float).reshape(-1)

print(len(train_history))

idx_valid = np.where(valid_np != -1)[0]

plt.plot(np.arange(train_np.size), train_np, label="Train Loss")
plt.plot(idx_valid, valid_np[idx_valid], label="Valid Loss")
plt.yscale("log")
plt.legend()
plt.show()
# Out:
# 5000

# %%
base, aux = get_slinky(properties)
valid = Dataset.load(valid_file)
pred = predict(final_model, base, aux, valid.idx_b, valid.xb, valid.lambdas)

# %%
animate(pred[0])

# %%
animate(valid.qs[0])

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import jax.numpy as jnp

n_cases = pred.shape[0]
colors = cm.viridis(jnp.linspace(0, 1, n_cases))

fig, ax = plt.subplots(figsize=(8, 5))

for i in range(n_cases):
    c = colors[i]

    # X
    ax.plot(pred[i, :, 4], color=c, linestyle='-')
    ax.plot(valid.qs[i, :, 4], color=c, linestyle='--')

    # Z
    ax.plot(pred[i, :, 6], color=c, linestyle='-', alpha=0.6)
    ax.plot(valid.qs[i, :, 6], color=c, linestyle='--', alpha=0.6)

pred_line = mlines.Line2D([], [], color='black', linestyle='-', label='Prediction')
truth_line = mlines.Line2D([], [], color='black', linestyle='--', label='Truth')
ax.legend(handles=[pred_line, truth_line])

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=0, vmax=n_cases - 1))
sm.set_array([])  # helps matplotlib know this is a valid mappable
fig.colorbar(sm, ax=ax, label='Case index i')

ax.set_title("Prediction vs Truth on Unseen BC")
ax.set_xlabel("lambda_idx")
ax.set_ylabel("Position (m)")
fig.tight_layout()
plt.show()

# %%
train = Dataset.load(train_file)
pred = predict(final_model, base, aux, train.idx_b, train.xb, train.lambdas)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import jax.numpy as jnp

n_cases = pred.shape[0]
colors = cm.viridis(jnp.linspace(0, 1, n_cases))

fig, ax = plt.subplots(figsize=(8, 5))

for i in range(n_cases):
    c = colors[i]

    # X
    ax.plot(pred[i, :, 4], color=c, linestyle='-')
    ax.plot(train.qs[i, :, 4], color=c, linestyle='--')

    # Z
    ax.plot(pred[i, :, 6], color=c, linestyle='-', alpha=0.6)
    ax.plot(train.qs[i, :, 6], color=c, linestyle='--', alpha=0.6)

pred_line = mlines.Line2D([], [], color='black', linestyle='-', label='Prediction')
truth_line = mlines.Line2D([], [], color='black', linestyle='--', label='Truth')
ax.legend(handles=[pred_line, truth_line])

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=0, vmax=n_cases - 1))
sm.set_array([])  # helps matplotlib know this is a valid mappable
fig.colorbar(sm, ax=ax, label='Case index i')

ax.set_title("Prediction vs Truth on Training BC")
ax.set_xlabel("lambda_idx")
ax.set_ylabel("Position (m)")
fig.tight_layout()
plt.show()
