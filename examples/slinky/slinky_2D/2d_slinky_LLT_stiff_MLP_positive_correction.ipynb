# %%
import numpy as np
import jax
import jax.numpy as jnp
import equinox as eqx
from jaxtyping import Float

import dismech_jax as djx

from util import *
from helpers import *
from animate import animate

jax.config.update("jax_enable_x64", True)

# %%
from Energy_NN_architectures import *

K_init = jnp.array([0.2, 0.0, 0.02])

# train_data = "../data/output_old.npz"
# valid_data = "../data/output_valid.npz"

# train_data = "../data/combined_output_new_train.npz"
# valid_data = "../data/combined_output_new_test.npz"

# train_file = "training_data.npz"
# valid_file = "validation_data.npz"
# # convert to direct-BC format
# convert_linear_bc_to_direct_bc(train_data, train_file, lambdas=None)
# convert_linear_bc_to_direct_bc(valid_data, valid_file, lambdas=None)


# train_file = "../experiment_data/train_dataset.npz"
# valid_file = "../experiment_data/test_dataset.npz"

train_file = "../experiment_data/combined_dataset.npz"
valid_file = "../experiment_data/combined_dataset.npz"

# %%
from properties import Properties

properties = Properties(
    length = 0.2,
    r0 = 0.005,
    axs = None,
    jxs = None,
    ixs1 = None,
    ixs2 = None,
    density = 800.0,
    E = 1e6,
    N = 3,
    # start = jax.numpy.array([0, 0, 0]),
    # end = jax.numpy.array([0.266166, 0., 0.01240256]),
    mass = 0.3
)

params = ModelParams(
    der_K=K_init,
    key=jax.random.PRNGKey(0),
    hidden=(10,),
    which_case="MLP",
    corr_factor=1,
    input_mode="raw",
    zero_reference=True,
    activation="tanh"
)

model_cls = CholeskyPlusStiffnessNN

# %%
from util import train_model
from util_energy_plots import EnergyLandscapeSpec, make_energy_snapshot_fn

spec = EnergyLandscapeSpec(
    strain_x_idx=0,
    strain_y_idx=3,
    triplet_idx=0,
    contour_style="lines",
    n_levels=20,
    show_colorbar=False,
    fixed_mode="first_path_point",
    strain_labels=["e0", "e1", "e2", "eb0", "eb1"],
    title="Energy contour during training",
    # better to fix these once known:
    xlim=(-4, 4.0),
    ylim=(0.0, 4.0),
)

snapshot_fn = make_energy_snapshot_fn(
    spec=spec,
    save_dir="energy_snapshots_LLT_stiff_MLP_positive_correction",
    use_valid=True,
    traj_idx=0,
    max_dlambda=5e-3,
    iters=5,
    ls_steps=10,
)

model, train_hist, valid_hist = train_model(
    properties=properties,
    model_cls=model_cls,
    params=params,
    train_file=train_file,
    valid_file=valid_file,
    n_epochs=1000,
    lr=5e-2,
    snapshot_fn=snapshot_fn,
    snapshot_every=200,
    valid_every=10,
    max_dlambda=5e-3,
    iters=5,
    ls_steps=10,
)
# Out:
# Epoch 000 | Train: 2.099e-04 | Valid: 1.008e-04
# Epoch 010 | Train: 3.635e-05 | Valid: 3.634e-05
# Epoch 020 | Train: 2.062e-05 | Valid: 2.101e-05
# Epoch 030 | Train: 1.485e-05 | Valid: 1.521e-05
# Epoch 040 | Train: 1.289e-05 | Valid: 1.263e-05
# Epoch 050 | Train: 9.318e-06 | Valid: 8.883e-06
# Epoch 060 | Train: 5.967e-06 | Valid: 5.701e-06
# Epoch 070 | Train: 4.167e-06 | Valid: 4.063e-06
# Epoch 080 | Train: 3.605e-06 | Valid: 3.579e-06
# Epoch 090 | Train: 3.193e-06 | Valid: 3.149e-06
# Epoch 100 | Train: 2.881e-06 | Valid: 2.856e-06
# Epoch 110 | Train: 2.611e-06 | Valid: 2.587e-06
# Epoch 120 | Train: 2.418e-06 | Valid: 2.402e-06
# Epoch 130 | Train: 2.282e-06 | Valid: 2.273e-06
# Epoch 140 | Train: 2.215e-06 | Valid: 2.211e-06
# Epoch 150 | Train: 2.180e-06 | Valid: 2.177e-06
# Epoch 160 | Train: 2.152e-06 | Valid: 2.149e-06
# Epoch 170 | Train: 2.127e-06 | Valid: 2.125e-06
# Epoch 180 | Train: 2.106e-06 | Valid: 2.104e-06
# Epoch 190 | Train: 2.087e-06 | Valid: 2.085e-06
# Epoch 200 | Train: 2.069e-06 | Valid: 2.067e-06
# Epoch 210 | Train: 2.052e-06 | Valid: 2.051e-06
# Epoch 220 | Train: 2.037e-06 | Valid: 2.035e-06
# Epoch 230 | Train: 2.022e-06 | Valid: 2.020e-06
# Epoch 240 | Train: 2.007e-06 | Valid: 2.006e-06
# Epoch 250 | Train: 1.993e-06 | Valid: 1.992e-06
# Epoch 260 | Train: 1.979e-06 | Valid: 1.978e-06
# Epoch 270 | Train: 1.966e-06 | Valid: 1.965e-06
# Epoch 280 | Train: 1.953e-06 | Valid: 1.952e-06
# Epoch 290 | Train: 1.941e-06 | Valid: 1.940e-06
# Epoch 300 | Train: 1.929e-06 | Valid: 1.928e-06
# Epoch 310 | Train: 1.917e-06 | Valid: 1.916e-06
# Epoch 320 | Train: 1.905e-06 | Valid: 1.904e-06
# Epoch 330 | Train: 1.894e-06 | Valid: 1.893e-06
# Epoch 340 | Train: 1.883e-06 | Valid: 1.882e-06
# Epoch 350 | Train: 1.872e-06 | Valid: 1.871e-06
# Epoch 360 | Train: 1.862e-06 | Valid: 1.861e-06
# Epoch 370 | Train: 1.851e-06 | Valid: 1.850e-06
# Epoch 380 | Train: 1.841e-06 | Valid: 1.840e-06
# Epoch 390 | Train: 1.831e-06 | Valid: 1.830e-06
# Epoch 400 | Train: 1.821e-06 | Valid: 1.820e-06
# Epoch 410 | Train: 1.811e-06 | Valid: 1.810e-06
# Epoch 420 | Train: 1.801e-06 | Valid: 1.800e-06
# Epoch 430 | Train: 1.791e-06 | Valid: 1.790e-06
# Epoch 440 | Train: 1.781e-06 | Valid: 1.780e-06
# Epoch 450 | Train: 1.771e-06 | Valid: 1.770e-06
# Epoch 460 | Train: 1.761e-06 | Valid: 1.760e-06
# Epoch 470 | Train: 1.751e-06 | Valid: 1.750e-06
# Epoch 480 | Train: 1.741e-06 | Valid: 1.740e-06
# Epoch 490 | Train: 1.731e-06 | Valid: 1.730e-06
# Epoch 500 | Train: 1.721e-06 | Valid: 1.720e-06
# Epoch 510 | Train: 1.711e-06 | Valid: 1.710e-06
# Epoch 520 | Train: 1.701e-06 | Valid: 1.700e-06
# Epoch 530 | Train: 1.692e-06 | Valid: 1.691e-06
# Epoch 540 | Train: 1.683e-06 | Valid: 1.682e-06
# Epoch 550 | Train: 1.673e-06 | Valid: 1.672e-06
# Epoch 560 | Train: 1.663e-06 | Valid: 1.662e-06
# Epoch 570 | Train: 1.653e-06 | Valid: 1.652e-06
# Epoch 580 | Train: 1.643e-06 | Valid: 1.642e-06
# Epoch 590 | Train: 1.630e-06 | Valid: 1.629e-06
# Epoch 600 | Train: 1.607e-06 | Valid: 1.626e-06
# Epoch 610 | Train: 1.617e-06 | Valid: 1.612e-06
# Epoch 620 | Train: 1.600e-06 | Valid: 1.594e-06
# Epoch 630 | Train: 1.583e-06 | Valid: 1.588e-06
# Epoch 640 | Train: 1.576e-06 | Valid: 1.574e-06
# Epoch 650 | Train: 1.567e-06 | Valid: 1.559e-06
# Epoch 660 | Train: 1.602e-06 | Valid: 1.568e-06
# Epoch 670 | Train: 4.493e-06 | Valid: 2.334e-06
# Epoch 680 | Train: 3.382e-06 | Valid: 3.297e-06
# Epoch 690 | Train: 2.649e-06 | Valid: 2.607e-06
# Epoch 700 | Train: 2.166e-06 | Valid: 2.167e-06
# Epoch 710 | Train: 2.027e-06 | Valid: 2.007e-06
# Epoch 720 | Train: 1.930e-06 | Valid: 1.923e-06
# Epoch 730 | Train: 1.861e-06 | Valid: 1.856e-06
# Epoch 740 | Train: 1.811e-06 | Valid: 1.807e-06
# Epoch 750 | Train: 1.768e-06 | Valid: 1.764e-06
# Epoch 760 | Train: 1.731e-06 | Valid: 1.728e-06
# Epoch 770 | Train: 1.701e-06 | Valid: 1.698e-06
# Epoch 780 | Train: 1.676e-06 | Valid: 1.673e-06
# Epoch 790 | Train: 1.655e-06 | Valid: 1.653e-06
# Epoch 800 | Train: 1.637e-06 | Valid: 1.636e-06
# Epoch 810 | Train: 1.622e-06 | Valid: 1.621e-06
# Epoch 820 | Train: 1.609e-06 | Valid: 1.607e-06
# Epoch 830 | Train: 1.597e-06 | Valid: 1.596e-06
# Epoch 840 | Train: 1.587e-06 | Valid: 1.586e-06
# Epoch 850 | Train: 1.578e-06 | Valid: 1.577e-06
# Epoch 860 | Train: 1.570e-06 | Valid: 1.569e-06
# Epoch 870 | Train: 1.563e-06 | Valid: 1.563e-06
# Epoch 880 | Train: 1.557e-06 | Valid: 1.556e-06
# Epoch 890 | Train: 1.551e-06 | Valid: 1.551e-06
# Epoch 900 | Train: 1.546e-06 | Valid: 1.546e-06
# Epoch 910 | Train: 1.541e-06 | Valid: 1.541e-06
# Epoch 920 | Train: 1.537e-06 | Valid: 1.536e-06
# Epoch 930 | Train: 1.533e-06 | Valid: 1.532e-06
# Epoch 940 | Train: 1.528e-06 | Valid: 1.528e-06
# Epoch 950 | Train: 1.524e-06 | Valid: 1.524e-06
# Epoch 960 | Train: 1.520e-06 | Valid: 1.520e-06
# Epoch 970 | Train: 1.517e-06 | Valid: 1.516e-06
# Epoch 980 | Train: 1.513e-06 | Valid: 1.512e-06
# Epoch 990 | Train: 1.509e-06 | Valid: 1.508e-06

# %%
import matplotlib.pyplot as plt
train_np = np.asarray(train_hist, dtype=float).reshape(-1)
valid_np = np.asarray(valid_hist, dtype=float).reshape(-1)

# print(len(train_history))

idx_valid = np.where(valid_np != -1)[0]

plt.plot(np.arange(train_np.size), train_np, label="Train Loss")
plt.plot(idx_valid, valid_np[idx_valid], label="Valid Loss")
plt.yscale("log")
plt.legend()
plt.show()

# %%
base, aux = get_slinky(properties)
valid = Dataset.load(valid_file)
pred = predict(model, base, aux, valid.idx_b, valid.xb, valid.lambdas)

# %%
animate(pred[0])

# %%
animate(valid.qs[0])

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import jax.numpy as jnp

n_cases = pred.shape[0]
colors = cm.viridis(jnp.linspace(0, 1, n_cases))

fig, ax = plt.subplots(figsize=(8, 5))

for i in range(n_cases):
    c = colors[i]

    # X
    ax.plot(pred[i, :, 4], color=c, linestyle='-')
    ax.plot(valid.qs[i, :, 4], color=c, linestyle='--')

    # Z
    ax.plot(pred[i, :, 6], color=c, linestyle='-', alpha=0.6)
    ax.plot(valid.qs[i, :, 6], color=c, linestyle='--', alpha=0.6)

pred_line = mlines.Line2D([], [], color='black', linestyle='-', label='Prediction')
truth_line = mlines.Line2D([], [], color='black', linestyle='--', label='Truth')
ax.legend(handles=[pred_line, truth_line])

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=0, vmax=n_cases - 1))
sm.set_array([])  # helps matplotlib know this is a valid mappable
fig.colorbar(sm, ax=ax, label='Case index i')

ax.set_title("Prediction vs Truth on Unseen BC")
ax.set_xlabel("lambda_idx")
ax.set_ylabel("Position (m)")
fig.tight_layout()
plt.show()

# %%
train = Dataset.load(train_file)
pred = predict(model, base, aux, train.idx_b, train.xb, train.lambdas)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
import jax.numpy as jnp

n_cases = pred.shape[0]
colors = cm.viridis(jnp.linspace(0, 1, n_cases))

fig, ax = plt.subplots(figsize=(8, 5))

for i in range(n_cases):
    c = colors[i]

    # X
    ax.plot(pred[i, :, 4], color=c, linestyle='-')
    ax.plot(train.qs[i, :, 4], color=c, linestyle='--')

    # Z
    ax.plot(pred[i, :, 6], color=c, linestyle='-', alpha=0.6)
    ax.plot(train.qs[i, :, 6], color=c, linestyle='--', alpha=0.6)

pred_line = mlines.Line2D([], [], color='black', linestyle='-', label='Prediction')
truth_line = mlines.Line2D([], [], color='black', linestyle='--', label='Truth')
ax.legend(handles=[pred_line, truth_line])

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=0, vmax=n_cases - 1))
sm.set_array([])  # helps matplotlib know this is a valid mappable
fig.colorbar(sm, ax=ax, label='Case index i')

ax.set_title("Prediction vs Truth on Training BC")
ax.set_xlabel("lambda_idx")
ax.set_ylabel("Position (m)")
fig.tight_layout()
plt.show()
